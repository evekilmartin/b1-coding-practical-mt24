# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Library/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/evekilmartin/.venvs/b1_codingprac/lib/python3.11/site-packages', '/Users/evekilmartin/Eng/Year 3/Code/B1 Scientific Coding/b1-coding-practical-mt24']

# %%
# Testing Part 3 of Assignment is functioning as expected
from uuv_mission.dynamic import Mission

mission_instance = Mission.from_csv("../data/mission.csv")
print("Reference:", mission_instance.reference)
print("Cave Height:", mission_instance.cave_height)
print("Cave Depth:", mission_instance.cave_depth)

#print(type(mission_instance.reference[1]))
# Out:
# Reference: [0.0, 2.9239130977932137, 5.514324158111004, 7.487585318696148, 8.65202856112426, 8.935843396822365, 8.396415579665113, 7.209734384872503, 5.641590146344928, 4.0051253736996015, 2.611426589237441, 1.720917456014432, 1.5031691037098716, 2.011404249992105, 3.175648661126249, 4.815541920877708, 6.670721591109058, 8.443927290710706, 9.849968676431626, 10.662778281967817, 10.75307161711013, 10.110615506739284, 8.84752915316426, 7.182030207066634, 5.405120925682013, 3.835402959415144, 2.7690901250201834, 2.4330608410378245, 2.948333781086039, 4.309732884422238, 6.384984238251617, 8.933452859036946, 11.641657643780652, 14.170078968633714, 16.20400695436713, 17.500546271145744, 17.92449464051056, 17.467552627807564, 16.24792900848622, 14.4904702442114, 12.490484048630206, 10.566968970689473, 9.012606152091674, 8.048358628976539, 7.789781725115566, 8.230292378244435, 9.243967567066706, 10.607363203101798, 12.03684861772606, 13.235508743141015, 13.942159952066, 13.974692819362351, 1
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Mission
from uuv_mission.dynamic import Submarine
from uuv_mission.dynamic import ClosedLoop
from uuv_mission.control import controller

sub = Submarine()
# Instantiate your controller (depending on your implementation)

closed_loop = ClosedLoop(sub, controller(0.15,0.6))
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
